# %% [markdown]
# # Εργαστηριακή Άσκηση 3: Βαθειά μάθηση.

# %% [markdown]
# # I. Στοιχεία ομάδας 19
#
#
# 1.   Χαράλαμπος Ρωσσίδης, ΑΜ: 03116701
# 2.   Νεκτάριος Ματσάγκος, ΑΜ: 03116709
# 3.   Δαμιανός Παππάς, ΑΜ: 03116608

# %% [markdown]
#  # Βαθιά μάθηση στο CIFAR-100

# %% [markdown]
# ## Εισαγωγή και επισκόπηση του συνόλου δεδομένων

# %%
from __future__ import absolute_import, division, print_function, unicode_literals # legacy compatibility

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# helper functions

# select from from_list elements with index in index_list
def select_from_list(from_list, index_list):
  filtered_list= [from_list[i] for i in index_list]
  return(filtered_list)

# append in filtered_list the index of each element of unfilterd_list if it exists in in target_list
def get_ds_index(unfiliterd_list, target_list):
  index = 0
  filtered_list=[]
  for i_ in unfiliterd_list:
    if i_[0] in target_list:
      filtered_list.append(index)
    index += 1
  return(filtered_list)

# select a url for a unique subset of CIFAR-100 with 20, 40, 60, or 80 classes
def select_classes_number(classes_number = 20):
  cifar100_20_classes_url = "https://pastebin.com/raw/nzE1n98V"
  cifar100_40_classes_url = "https://pastebin.com/raw/zGX4mCNP"
  cifar100_60_classes_url = "https://pastebin.com/raw/nsDTd3Qn"
  cifar100_80_classes_url = "https://pastebin.com/raw/SNbXz700"
  if classes_number == 20:
    return cifar100_20_classes_url
  elif classes_number == 40:
    return cifar100_40_classes_url
  elif classes_number == 60:
    return cifar100_60_classes_url
  elif classes_number == 80:
    return cifar100_80_classes_url
  else:
    return -1

# %%
# load the entire dataset
(x_train_all, y_train_all), (x_test_all, y_test_all) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 2s 0us/step

# %%
print(x_train_all.shape)
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# Η κάθε ομάδα θα δουλέψει με ένα μοναδικό ξεχωριστό υποσύνολο του CIFAR-100
# Στο επόμενο κελί, αντικαταστήστε την τιμή της μεταβλητής `team_seed` με τον αριθμό της ομάδας σας.

# %%
# REPLACE WITH YOUR TEAM NUMBER
team_seed = 19

# %% [markdown]
# Στο επόμενο κελί μπορείτε να διαλέξετε το πλήθος των κατηγορίων σας: 20 (default), 40, 60 ή 80.

# %%
# select the number of classes
cifar100_classes_url = select_classes_number()

# %% [markdown]
# Δημιουργούμε το μοναδικό dataset της ομάδας μας:

# %%
team_classes = pd.read_csv(cifar100_classes_url, sep=',', header=None)
CIFAR100_LABELS_LIST = pd.read_csv('https://pastebin.com/raw/qgDaNggt', sep=',', header=None).astype(str).values.tolist()[0]

our_index = team_classes.iloc[team_seed,:].values.tolist()
our_classes = select_from_list(CIFAR100_LABELS_LIST, our_index)
train_index = get_ds_index(y_train_all, our_index)
test_index = get_ds_index(y_test_all, our_index)

x_train_ds = np.asarray(select_from_list(x_train_all, train_index))
y_train_ds = np.asarray(select_from_list(y_train_all, train_index))
x_test_ds = np.asarray(select_from_list(x_test_all, test_index))
y_test_ds = np.asarray(select_from_list(y_test_all, test_index))

# %%
# print our classes
print(our_classes)
# Out:
# [' bear', ' bottle', ' bus', ' camel', ' crocodile', ' flatfish', ' fox', ' keyboard', ' lamp', ' lawn_mower', ' lobster', ' motorcycle', ' mushroom', ' palm_tree', ' porcupine', ' seal', ' streetcar', ' sunflower', ' telephone', ' woman']

# %%
CLASSES_NUM=len(our_classes)

# %%
print(x_train_ds[1].shape)
# Out:
# (32, 32, 3)

# %%
# get (train) dataset dimensions
data_size, img_rows, img_cols, img_channels = x_train_ds.shape

# set validation set percentage (wrt the training set size)
validation_percentage = 0.15
val_size = round(validation_percentage * data_size)

# Reserve val_size samples for validation and normalize all values
x_val = x_train_ds[-val_size:]/255
y_val = y_train_ds[-val_size:]
x_train = x_train_ds[:-val_size]/255
y_train = y_train_ds[:-val_size]
x_test = x_test_ds/255
y_test = y_test_ds

print(len(x_val))

# summarize loaded dataset
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

# get class label from class index
def class_label_from_index(fine_category):
  return(CIFAR100_LABELS_LIST[fine_category.item(0)])

# plot first few images
plt.figure(figsize=(6, 6))
for i in range(9):
	# define subplot
  plt.subplot(330 + 1 + i).set_title(class_label_from_index(y_train[i]))
	# plot raw pixel data
  plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
  #show the figure
plt.show()
# Out:
# 1500
# Train: X=(8500, 32, 32, 3), y=(8500, 1)
# Validation: X=(1500, 32, 32, 3), y=(1500, 1)
# Test: X=(2000, 32, 32, 3), y=(2000, 1)

# %% [markdown]
# ## Συναρτήσεις εκπαίδευσης

# %% [markdown]
# Θα χρησιμοποιήσουμε την ιδιότητα data prefetch του tf2:

# %%
# we user prefetch https://www.tensorflow.org/api_docs/python/tf/data/Dataset#prefetch 
# see also AUTOTUNE
# the dataset is now "infinite"

BATCH_SIZE = 128
AUTOTUNE = tf.data.experimental.AUTOTUNE # https://www.tensorflow.org/guide/data_performance

def _input_fn(x,y, BATCH_SIZE):
  ds = tf.data.Dataset.from_tensor_slices((x,y))
  ds = ds.shuffle(buffer_size=data_size)
  ds = ds.repeat()
  ds = ds.batch(BATCH_SIZE)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

train_ds =_input_fn(x_train,y_train, BATCH_SIZE) #PrefetchDataset object
validation_ds =_input_fn(x_val,y_val, BATCH_SIZE) #PrefetchDataset object
test_ds =_input_fn(x_test,y_test, BATCH_SIZE) #PrefetchDataset object

# steps_per_epoch and validation_steps for training and validation: https://www.tensorflow.org/guide/keras/train_and_evaluate

def train_model(model, epochs = 10, steps_per_epoch = 2, validation_steps = 1):
  history = model.fit(train_ds, epochs=epochs, steps_per_epoch=steps_per_epoch, validation_data=validation_ds, validation_steps=validation_steps)
  return(history)

# %% [markdown]
# ## Γραφικές παραστάσεις εκπαίδευσης και απόδοση στο σύνολο ελέγχου

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
	plt.figure(figsize=(8, 8))
	plt.suptitle('Training Curves')
	# plot loss
	plt.subplot(211)
	plt.title('Cross Entropy Loss')
	plt.plot(history.history['loss'], color='blue', label='train')
	plt.plot(history.history['val_loss'], color='orange', label='val')
	plt.legend(loc='upper right')
	# plot accuracy
	plt.subplot(212)
	plt.title('Classification Accuracy')
	plt.plot(history.history['accuracy'], color='blue', label='train')
	plt.plot(history.history['val_accuracy'], color='orange', label='val')
	plt.legend(loc='lower right')
	return plt
 
# print test set evaluation metrics
def model_evaluation(model, evaluation_steps):
	print('\nTest set evaluation metrics')
	loss0,accuracy0 = model.evaluate(test_ds, steps = evaluation_steps)
	print("loss: {:.2f}".format(loss0))
	print("accuracy: {:.2f}".format(accuracy0))

def model_report(model, history, evaluation_steps = 10):
	plt = summarize_diagnostics(history)
	plt.show()
	model_evaluation(model, evaluation_steps)

# %% [markdown]
# ## Μοντέλα δικτύων

# %% [markdown]
# ### Ένα μικρό συνελικτικό δίκτυο "from scratch"

# %%
# a simple CNN https://www.tensorflow.org/tutorials/images/cnn

def init_simple_model(summary):
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32,32,3)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Flatten())
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(100, activation='softmax'))
  
  model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.0001), loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=["accuracy"])
  if summary: 
    model.summary()
  return model

# %%
SIMPLE_MODEL = init_simple_model(summary = True)
SIMPLE_MODEL_history = train_model(SIMPLE_MODEL, 50, 30, 5)
model_report(SIMPLE_MODEL, SIMPLE_MODEL_history, 30)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               6500
# =================================================================
# Total params: 128,420
# Trainable params: 128,420
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 30/30 [==============================] - 8s 23ms/step - loss: 4.5581 - accuracy: 0.0269 - val_loss: 4.3477 - val_accuracy: 0.0500
# Epoch 2/50
# 30/30 [==============================] - 0s 10ms/step - loss: 4.2313 - accuracy: 0.0488 - val_loss: 3.8679 - val_accuracy: 0.0547
# Epoch 3/50
# 30/30 [==============================] - 0s 10ms/step - loss: 3.8155 - accuracy: 0.0692 - val_loss: 3.6019 - val_accuracy: 0.0703
# Epoch 4/50
# 30/30 [==============================] - 0s 10ms/step - loss: 3.5341 - accuracy: 0.0708 - val_loss: 3.3769 - val_accuracy: 0.0969
# Epoch 5/50
# 30/30 [==============================] - 0s 10ms/step - loss: 3.3700 - accuracy: 0.0928 - val_loss: 3.2215 - val_accuracy: 0.1094
# Epoch 6/50
# 30/30 [==============================] - 0s 9ms/step - loss: 3.2464 - accuracy: 0.1090 - val_loss: 3.1093 - val_accuracy: 0.1219
# Epoch 7/50
# 30/30 [==============================] - 0s 10ms/step - loss: 3.0592 - accuracy: 0.1182 - val_loss: 2.9308 - val_accuracy: 0.0953
# Epoch 8/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.9306 - accuracy: 0.1118 - val_loss: 2.7676 - val_accuracy: 0.1672
# Epoch 9/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.8123 - accuracy: 0.1406 - val_loss: 2.7804 - val_accuracy: 0.1391
# Epoch 10/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.7978 - accuracy: 0.1467 - val_loss: 2.6983 - val_accuracy: 0.1625
# Epoch 11/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.7595 - accuracy: 0.1450 - val_loss: 2.7264 - val_accuracy: 0.1484
# Epoch 12/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.7265 - accuracy: 0.1676 - val_loss: 2.7216 - val_accuracy: 0.1766
# Epoch 13/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.6936 - accuracy: 0.1750 - val_loss: 2.7204 - val_accuracy: 0.1578
# Epoch 14/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.6953 - accuracy: 0.1764 - val_loss: 2.6741 - val_accuracy: 0.1937
# Epoch 15/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.6652 - accuracy: 0.1860 - val_loss: 2.6690 - val_accuracy: 0.2016
# Epoch 16/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.6639 - accuracy: 0.1986 - val_loss: 2.6408 - val_accuracy: 0.2047
# Epoch 17/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.6575 - accuracy: 0.1958 - val_loss: 2.6664 - val_accuracy: 0.2219
# Epoch 18/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5992 - accuracy: 0.2218 - val_loss: 2.5994 - val_accuracy: 0.2219
# Epoch 19/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.6240 - accuracy: 0.2138 - val_loss: 2.5478 - val_accuracy: 0.2766
# Epoch 20/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5847 - accuracy: 0.2203 - val_loss: 2.5533 - val_accuracy: 0.2656
# Epoch 21/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5732 - accuracy: 0.2273 - val_loss: 2.5724 - val_accuracy: 0.2422
# Epoch 22/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5583 - accuracy: 0.2349 - val_loss: 2.5631 - val_accuracy: 0.2531
# Epoch 23/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5547 - accuracy: 0.2324 - val_loss: 2.5460 - val_accuracy: 0.2359
# Epoch 24/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.5206 - accuracy: 0.2318 - val_loss: 2.5221 - val_accuracy: 0.2453
# Epoch 25/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.5480 - accuracy: 0.2225 - val_loss: 2.5362 - val_accuracy: 0.2531
# Epoch 26/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.4949 - accuracy: 0.2554 - val_loss: 2.5341 - val_accuracy: 0.2531
# Epoch 27/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.4974 - accuracy: 0.2527 - val_loss: 2.4851 - val_accuracy: 0.2625
# Epoch 28/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.4510 - accuracy: 0.2776 - val_loss: 2.4620 - val_accuracy: 0.2922
# Epoch 29/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.4746 - accuracy: 0.2625 - val_loss: 2.4643 - val_accuracy: 0.2875
# Epoch 30/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.4574 - accuracy: 0.2650 - val_loss: 2.5146 - val_accuracy: 0.2375
# Epoch 31/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.4087 - accuracy: 0.2939 - val_loss: 2.4913 - val_accuracy: 0.2766
# Epoch 32/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.4569 - accuracy: 0.2654 - val_loss: 2.4390 - val_accuracy: 0.2859
# Epoch 33/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.4138 - accuracy: 0.2888 - val_loss: 2.4132 - val_accuracy: 0.2766
# Epoch 34/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.3985 - accuracy: 0.2761 - val_loss: 2.4371 - val_accuracy: 0.2781
# Epoch 35/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.3824 - accuracy: 0.2877 - val_loss: 2.4748 - val_accuracy: 0.2500
# Epoch 36/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.3679 - accuracy: 0.2842 - val_loss: 2.4978 - val_accuracy: 0.2484
# Epoch 37/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.3980 - accuracy: 0.2886 - val_loss: 2.3819 - val_accuracy: 0.3016
# Epoch 38/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.3335 - accuracy: 0.3060 - val_loss: 2.3866 - val_accuracy: 0.3266
# Epoch 39/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.3552 - accuracy: 0.3033 - val_loss: 2.3593 - val_accuracy: 0.2969
# Epoch 40/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.3397 - accuracy: 0.3040 - val_loss: 2.3710 - val_accuracy: 0.3078
# Epoch 41/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2941 - accuracy: 0.3209 - val_loss: 2.3604 - val_accuracy: 0.3172
# Epoch 42/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2940 - accuracy: 0.3102 - val_loss: 2.3327 - val_accuracy: 0.3078
# Epoch 43/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2877 - accuracy: 0.3172 - val_loss: 2.2650 - val_accuracy: 0.3422
# Epoch 44/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2646 - accuracy: 0.3250 - val_loss: 2.3011 - val_accuracy: 0.3344
# Epoch 45/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2520 - accuracy: 0.3293 - val_loss: 2.3160 - val_accuracy: 0.3172
# Epoch 46/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2615 - accuracy: 0.3253 - val_loss: 2.2949 - val_accuracy: 0.3109
# Epoch 47/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.2707 - accuracy: 0.3349 - val_loss: 2.3180 - val_accuracy: 0.3172
# Epoch 48/50
# 30/30 [==============================] - 0s 10ms/step - loss: 2.1831 - accuracy: 0.3622 - val_loss: 2.2639 - val_accuracy: 0.3500
# Epoch 49/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.2537 - accuracy: 0.3095 - val_loss: 2.2752 - val_accuracy: 0.3328
# Epoch 50/50
# 30/30 [==============================] - 0s 9ms/step - loss: 2.1980 - accuracy: 0.3360 - val_loss: 2.2983 - val_accuracy: 0.3187
# Test set evaluation metrics
# 30/30 [==============================] - 0s 4ms/step - loss: 2.2312 - accuracy: 0.3393
# loss: 2.23
# accuracy: 0.34

# %% [markdown]
# # From Scratch με τροποποιήσεις

# %%
# a simple CNN https://www.tensorflow.org/tutorials/images/cnn

def init_simple_model(summary):
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='elu', padding='same', input_shape=(32,32,3)))
  model.add(layers.Conv2D(32, (3, 3), activation='elu', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.25))
  model.add(layers.Conv2D(32, (3, 3), activation='elu', padding='same'))
  model.add(layers.Conv2D(64, (3, 3), activation='elu', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.25))
  model.add(layers.Conv2D(64, (3, 3), activation='elu', padding='same'))
  model.add(layers.Conv2D(64, (3, 3), activation='elu', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.25))

  model.add(layers.Flatten())
  model.add(layers.Dense(64, activation='elu'))
  model.add(layers.Dropout(0.25))
  model.add(layers.Dense(100, activation='softmax'))
  model.compile(optimizer=tf.keras.optimizers.Adam(0.0001), loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=["accuracy"])
  if summary: 
    model.summary()
  return model

# %%
SIMPLE_MODEL = init_simple_model(summary = True)
SIMPLE_MODEL_history = train_model(SIMPLE_MODEL, 250, 50, 5)
model_report(SIMPLE_MODEL, SIMPLE_MODEL_history, 30)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               6500
# =================================================================
# Total params: 134,692
# Trainable params: 134,692
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/250
# 50/50 [==============================] - 2s 16ms/step - loss: 4.3764 - accuracy: 0.0303 - val_loss: 3.7667 - val_accuracy: 0.0359
# Epoch 2/250
# 50/50 [==============================] - 1s 13ms/step - loss: 3.7848 - accuracy: 0.0527 - val_loss: 3.4730 - val_accuracy: 0.0453
# Epoch 3/250
# 50/50 [==============================] - 1s 13ms/step - loss: 3.5644 - accuracy: 0.0550 - val_loss: 3.3334 - val_accuracy: 0.0734
# Epoch 4/250
# 50/50 [==============================] - 1s 13ms/step - loss: 3.4312 - accuracy: 0.0538 - val_loss: 3.2389 - val_accuracy: 0.0641
# Epoch 5/250
# 50/50 [==============================] - 1s 13ms/step - loss: 3.3331 - accuracy: 0.0656 - val_loss: 3.1580 - val_accuracy: 0.1000
# Epoch 6/250
# 50/50 [==============================] - 1s 13ms/step - loss: 3.2500 - accuracy: 0.0672 - val_loss: 3.0497 - val_accuracy: 0.1031
# Epoch 7/250
# 50/50 [==============================] - 1s 13ms/step - loss: 3.1591 - accuracy: 0.0785 - val_loss: 2.9639 - val_accuracy: 0.1312
# Epoch 8/250
# 50/50 [==============================] - 1s 13ms/step - loss: 3.0900 - accuracy: 0.0909 - val_loss: 2.8950 - val_accuracy: 0.1531
# Epoch 9/250
# 50/50 [==============================] - 1s 13ms/step - loss: 3.0449 - accuracy: 0.1046 - val_loss: 2.8399 - val_accuracy: 0.1828
# Epoch 10/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.9837 - accuracy: 0.1105 - val_loss: 2.7912 - val_accuracy: 0.2031
# Epoch 11/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.9522 - accuracy: 0.1117 - val_loss: 2.7593 - val_accuracy: 0.1969
# Epoch 12/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.9160 - accuracy: 0.1272 - val_loss: 2.7697 - val_accuracy: 0.1750
# Epoch 13/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.8581 - accuracy: 0.1448 - val_loss: 2.6579 - val_accuracy: 0.2359
# Epoch 14/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.8247 - accuracy: 0.1525 - val_loss: 2.6494 - val_accuracy: 0.2281
# Epoch 15/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.7660 - accuracy: 0.1671 - val_loss: 2.5690 - val_accuracy: 0.2750
# Epoch 16/250
# 50/50 [==============================] - 1s 14ms/step - loss: 2.7321 - accuracy: 0.1794 - val_loss: 2.5682 - val_accuracy: 0.2672
# Epoch 17/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.6746 - accuracy: 0.1938 - val_loss: 2.5489 - val_accuracy: 0.2703
# Epoch 18/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.6617 - accuracy: 0.2040 - val_loss: 2.4349 - val_accuracy: 0.2984
# Epoch 19/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.5915 - accuracy: 0.2284 - val_loss: 2.4430 - val_accuracy: 0.2937
# Epoch 20/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.5767 - accuracy: 0.2277 - val_loss: 2.3743 - val_accuracy: 0.3125
# Epoch 21/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.5247 - accuracy: 0.2410 - val_loss: 2.3618 - val_accuracy: 0.3172
# Epoch 22/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.4976 - accuracy: 0.2470 - val_loss: 2.3328 - val_accuracy: 0.3219
# Epoch 23/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.4596 - accuracy: 0.2668 - val_loss: 2.3199 - val_accuracy: 0.3328
# Epoch 24/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.3973 - accuracy: 0.2919 - val_loss: 2.1703 - val_accuracy: 0.3719
# Epoch 25/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.3983 - accuracy: 0.2885 - val_loss: 2.1934 - val_accuracy: 0.3719
# Epoch 26/250
# 50/50 [==============================] - 1s 14ms/step - loss: 2.3695 - accuracy: 0.2865 - val_loss: 2.2237 - val_accuracy: 0.3594
# Epoch 27/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.3431 - accuracy: 0.2947 - val_loss: 2.2076 - val_accuracy: 0.3375
# Epoch 28/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.3241 - accuracy: 0.2991 - val_loss: 2.0870 - val_accuracy: 0.4031
# Epoch 29/250
# 50/50 [==============================] - 1s 14ms/step - loss: 2.3101 - accuracy: 0.3123 - val_loss: 2.1358 - val_accuracy: 0.3875
# Epoch 30/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.2809 - accuracy: 0.3105 - val_loss: 2.1362 - val_accuracy: 0.3812
# Epoch 31/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.2675 - accuracy: 0.3203 - val_loss: 2.1429 - val_accuracy: 0.3969
# Epoch 32/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.2691 - accuracy: 0.3157 - val_loss: 2.0698 - val_accuracy: 0.3859
# Epoch 33/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.2126 - accuracy: 0.3331 - val_loss: 2.0279 - val_accuracy: 0.4234
# Epoch 34/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.2090 - accuracy: 0.3340 - val_loss: 1.9895 - val_accuracy: 0.3938
# Epoch 35/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.1701 - accuracy: 0.3523 - val_loss: 2.0671 - val_accuracy: 0.3891
# Epoch 36/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.2005 - accuracy: 0.3349 - val_loss: 2.0163 - val_accuracy: 0.4016
# Epoch 37/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.1282 - accuracy: 0.3662 - val_loss: 2.0188 - val_accuracy: 0.4047
# Epoch 38/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.1017 - accuracy: 0.3631 - val_loss: 1.9686 - val_accuracy: 0.4328
# Epoch 39/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.1349 - accuracy: 0.3567 - val_loss: 2.0042 - val_accuracy: 0.4047
# Epoch 40/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.1048 - accuracy: 0.3646 - val_loss: 2.0074 - val_accuracy: 0.4031
# Epoch 41/250
# 50/50 [==============================] - 1s 14ms/step - loss: 2.1024 - accuracy: 0.3775 - val_loss: 2.0039 - val_accuracy: 0.4000
# Epoch 42/250
# 50/50 [==============================] - 1s 14ms/step - loss: 2.0956 - accuracy: 0.3695 - val_loss: 1.8742 - val_accuracy: 0.4531
# Epoch 43/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.0618 - accuracy: 0.3695 - val_loss: 1.9850 - val_accuracy: 0.3922
# Epoch 44/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.0642 - accuracy: 0.3702 - val_loss: 1.9354 - val_accuracy: 0.4266
# Epoch 45/250
# 50/50 [==============================] - 1s 14ms/step - loss: 2.0779 - accuracy: 0.3778 - val_loss: 1.9462 - val_accuracy: 0.4297
# Epoch 46/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.0133 - accuracy: 0.3895 - val_loss: 1.9221 - val_accuracy: 0.4391
# Epoch 47/250
# 50/50 [==============================] - 1s 13ms/step - loss: 2.0198 - accuracy: 0.3927 - val_loss: 1.9167 - val_accuracy: 0.4266
# Epoch 48/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.9939 - accuracy: 0.3995 - val_loss: 1.9733 - val_accuracy: 0.4062
# Epoch 49/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.9829 - accuracy: 0.4007 - val_loss: 1.8715 - val_accuracy: 0.4422
# Epoch 50/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.9970 - accuracy: 0.3987 - val_loss: 1.7958 - val_accuracy: 0.4609
# Epoch 51/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.9602 - accuracy: 0.4048 - val_loss: 1.9140 - val_accuracy: 0.4406
# Epoch 52/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.9510 - accuracy: 0.4025 - val_loss: 1.8363 - val_accuracy: 0.4437
# Epoch 53/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.9629 - accuracy: 0.4127 - val_loss: 1.7917 - val_accuracy: 0.4453
# Epoch 54/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.9523 - accuracy: 0.4023 - val_loss: 1.8470 - val_accuracy: 0.4250
# Epoch 55/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.9281 - accuracy: 0.4276 - val_loss: 1.7778 - val_accuracy: 0.4672
# Epoch 56/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.9116 - accuracy: 0.4150 - val_loss: 1.8110 - val_accuracy: 0.4406
# Epoch 57/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.9130 - accuracy: 0.4201 - val_loss: 1.8679 - val_accuracy: 0.4453
# Epoch 58/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.8987 - accuracy: 0.4232 - val_loss: 1.8002 - val_accuracy: 0.4547
# Epoch 59/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.8735 - accuracy: 0.4330 - val_loss: 1.8489 - val_accuracy: 0.4219
# Epoch 60/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.8480 - accuracy: 0.4533 - val_loss: 1.7215 - val_accuracy: 0.4906
# Epoch 61/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.9021 - accuracy: 0.4269 - val_loss: 1.7785 - val_accuracy: 0.4750
# Epoch 62/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.8328 - accuracy: 0.4359 - val_loss: 1.8172 - val_accuracy: 0.4672
# Epoch 63/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.8337 - accuracy: 0.4440 - val_loss: 1.7916 - val_accuracy: 0.4625
# Epoch 64/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.8505 - accuracy: 0.4375 - val_loss: 1.7697 - val_accuracy: 0.4578
# Epoch 65/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.7984 - accuracy: 0.4598 - val_loss: 1.7294 - val_accuracy: 0.4766
# Epoch 66/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.8189 - accuracy: 0.4437 - val_loss: 1.7032 - val_accuracy: 0.4797
# Epoch 67/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.8068 - accuracy: 0.4428 - val_loss: 1.7611 - val_accuracy: 0.4656
# Epoch 68/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.8230 - accuracy: 0.4555 - val_loss: 1.7669 - val_accuracy: 0.4625
# Epoch 69/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.8198 - accuracy: 0.4374 - val_loss: 1.7089 - val_accuracy: 0.4453
# Epoch 70/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.7881 - accuracy: 0.4494 - val_loss: 1.6518 - val_accuracy: 0.5000
# Epoch 71/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.7767 - accuracy: 0.4597 - val_loss: 1.7617 - val_accuracy: 0.4563
# Epoch 72/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.7793 - accuracy: 0.4583 - val_loss: 1.6929 - val_accuracy: 0.4781
# Epoch 73/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.7652 - accuracy: 0.4559 - val_loss: 1.6493 - val_accuracy: 0.5203
# Epoch 74/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.7579 - accuracy: 0.4716 - val_loss: 1.7347 - val_accuracy: 0.4953
# Epoch 75/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.7357 - accuracy: 0.4766 - val_loss: 1.7065 - val_accuracy: 0.4828
# Epoch 76/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.7435 - accuracy: 0.4578 - val_loss: 1.7146 - val_accuracy: 0.4828
# Epoch 77/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.7424 - accuracy: 0.4728 - val_loss: 1.6737 - val_accuracy: 0.4984
# Epoch 78/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.7244 - accuracy: 0.4686 - val_loss: 1.7129 - val_accuracy: 0.4781
# Epoch 79/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.7008 - accuracy: 0.4827 - val_loss: 1.6237 - val_accuracy: 0.5125
# Epoch 80/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.7366 - accuracy: 0.4688 - val_loss: 1.6872 - val_accuracy: 0.4938
# Epoch 81/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.7222 - accuracy: 0.4790 - val_loss: 1.6584 - val_accuracy: 0.4984
# Epoch 82/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.6674 - accuracy: 0.4924 - val_loss: 1.7027 - val_accuracy: 0.4844
# Epoch 83/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.6807 - accuracy: 0.4866 - val_loss: 1.7018 - val_accuracy: 0.4734
# Epoch 84/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.6610 - accuracy: 0.4886 - val_loss: 1.6158 - val_accuracy: 0.4922
# Epoch 85/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.6988 - accuracy: 0.4829 - val_loss: 1.7253 - val_accuracy: 0.4734
# Epoch 86/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.6658 - accuracy: 0.4795 - val_loss: 1.6148 - val_accuracy: 0.5016
# Epoch 87/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.6264 - accuracy: 0.5016 - val_loss: 1.6514 - val_accuracy: 0.5000
# Epoch 88/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.6503 - accuracy: 0.4882 - val_loss: 1.6438 - val_accuracy: 0.4922
# Epoch 89/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.6493 - accuracy: 0.4975 - val_loss: 1.6578 - val_accuracy: 0.4891
# Epoch 90/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.6462 - accuracy: 0.4924 - val_loss: 1.5817 - val_accuracy: 0.5281
# Epoch 91/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.6133 - accuracy: 0.5062 - val_loss: 1.6536 - val_accuracy: 0.4984
# Epoch 92/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.6098 - accuracy: 0.5056 - val_loss: 1.7532 - val_accuracy: 0.4906
# Epoch 93/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.6091 - accuracy: 0.4944 - val_loss: 1.5874 - val_accuracy: 0.5312
# Epoch 94/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.6034 - accuracy: 0.4993 - val_loss: 1.6265 - val_accuracy: 0.5078
# Epoch 95/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.5864 - accuracy: 0.5216 - val_loss: 1.6737 - val_accuracy: 0.4938
# Epoch 96/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.6144 - accuracy: 0.5055 - val_loss: 1.5573 - val_accuracy: 0.5375
# Epoch 97/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.5846 - accuracy: 0.5073 - val_loss: 1.5997 - val_accuracy: 0.5266
# Epoch 98/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.5576 - accuracy: 0.5196 - val_loss: 1.6600 - val_accuracy: 0.4984
# Epoch 99/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.6081 - accuracy: 0.5075 - val_loss: 1.5410 - val_accuracy: 0.5281
# Epoch 100/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.5941 - accuracy: 0.5031 - val_loss: 1.5736 - val_accuracy: 0.5266
# Epoch 101/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.5745 - accuracy: 0.5163 - val_loss: 1.5480 - val_accuracy: 0.5437
# Epoch 102/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.5936 - accuracy: 0.5090 - val_loss: 1.5125 - val_accuracy: 0.5547
# Epoch 103/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.5057 - accuracy: 0.5361 - val_loss: 1.5066 - val_accuracy: 0.5531
# Epoch 104/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.5772 - accuracy: 0.5059 - val_loss: 1.5748 - val_accuracy: 0.5266
# Epoch 105/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.5274 - accuracy: 0.5295 - val_loss: 1.6206 - val_accuracy: 0.5344
# Epoch 106/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.5419 - accuracy: 0.5260 - val_loss: 1.5628 - val_accuracy: 0.5312
# Epoch 107/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.5303 - accuracy: 0.5277 - val_loss: 1.6587 - val_accuracy: 0.5078
# Epoch 108/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.5217 - accuracy: 0.5266 - val_loss: 1.5247 - val_accuracy: 0.5391
# Epoch 109/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.5124 - accuracy: 0.5259 - val_loss: 1.5996 - val_accuracy: 0.5172
# Epoch 110/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.5068 - accuracy: 0.5371 - val_loss: 1.5754 - val_accuracy: 0.5406
# Epoch 111/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.5207 - accuracy: 0.5329 - val_loss: 1.5213 - val_accuracy: 0.5500
# Epoch 112/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.5050 - accuracy: 0.5362 - val_loss: 1.5507 - val_accuracy: 0.5406
# Epoch 113/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.4819 - accuracy: 0.5449 - val_loss: 1.4779 - val_accuracy: 0.5656
# Epoch 114/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4725 - accuracy: 0.5412 - val_loss: 1.6067 - val_accuracy: 0.5469
# Epoch 115/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.5101 - accuracy: 0.5361 - val_loss: 1.5150 - val_accuracy: 0.5484
# Epoch 116/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4951 - accuracy: 0.5337 - val_loss: 1.5410 - val_accuracy: 0.5391
# Epoch 117/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.4753 - accuracy: 0.5414 - val_loss: 1.4684 - val_accuracy: 0.5500
# Epoch 118/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4846 - accuracy: 0.5367 - val_loss: 1.5481 - val_accuracy: 0.5672
# Epoch 119/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4578 - accuracy: 0.5449 - val_loss: 1.4736 - val_accuracy: 0.5516
# Epoch 120/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4563 - accuracy: 0.5472 - val_loss: 1.4986 - val_accuracy: 0.5516
# Epoch 121/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4890 - accuracy: 0.5371 - val_loss: 1.4875 - val_accuracy: 0.5453
# Epoch 122/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4526 - accuracy: 0.5438 - val_loss: 1.4681 - val_accuracy: 0.5609
# Epoch 123/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4745 - accuracy: 0.5413 - val_loss: 1.5206 - val_accuracy: 0.5344
# Epoch 124/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.4776 - accuracy: 0.5467 - val_loss: 1.5129 - val_accuracy: 0.5484
# Epoch 125/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.4632 - accuracy: 0.5453 - val_loss: 1.4903 - val_accuracy: 0.5688
# Epoch 126/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4263 - accuracy: 0.5586 - val_loss: 1.5175 - val_accuracy: 0.5516
# Epoch 127/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4251 - accuracy: 0.5600 - val_loss: 1.4801 - val_accuracy: 0.5625
# Epoch 128/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4077 - accuracy: 0.5536 - val_loss: 1.4831 - val_accuracy: 0.5609
# Epoch 129/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4145 - accuracy: 0.5603 - val_loss: 1.5066 - val_accuracy: 0.5344
# Epoch 130/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4260 - accuracy: 0.5469 - val_loss: 1.4577 - val_accuracy: 0.5625
# Epoch 131/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3990 - accuracy: 0.5620 - val_loss: 1.5723 - val_accuracy: 0.5328
# Epoch 132/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.4646 - accuracy: 0.5391 - val_loss: 1.5709 - val_accuracy: 0.5359
# Epoch 133/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4251 - accuracy: 0.5608 - val_loss: 1.4918 - val_accuracy: 0.5641
# Epoch 134/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4073 - accuracy: 0.5537 - val_loss: 1.4058 - val_accuracy: 0.5625
# Epoch 135/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.4068 - accuracy: 0.5646 - val_loss: 1.5090 - val_accuracy: 0.5500
# Epoch 136/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3657 - accuracy: 0.5718 - val_loss: 1.5076 - val_accuracy: 0.5406
# Epoch 137/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3963 - accuracy: 0.5711 - val_loss: 1.4258 - val_accuracy: 0.5891
# Epoch 138/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.3932 - accuracy: 0.5649 - val_loss: 1.4609 - val_accuracy: 0.5594
# Epoch 139/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3854 - accuracy: 0.5622 - val_loss: 1.3826 - val_accuracy: 0.5813
# Epoch 140/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.3737 - accuracy: 0.5725 - val_loss: 1.4523 - val_accuracy: 0.5797
# Epoch 141/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3633 - accuracy: 0.5794 - val_loss: 1.4740 - val_accuracy: 0.5625
# Epoch 142/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3659 - accuracy: 0.5782 - val_loss: 1.4525 - val_accuracy: 0.5656
# Epoch 143/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.3563 - accuracy: 0.5734 - val_loss: 1.5297 - val_accuracy: 0.5359
# Epoch 144/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.3547 - accuracy: 0.5798 - val_loss: 1.3881 - val_accuracy: 0.5859
# Epoch 145/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3885 - accuracy: 0.5632 - val_loss: 1.4215 - val_accuracy: 0.5781
# Epoch 146/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3378 - accuracy: 0.5812 - val_loss: 1.4733 - val_accuracy: 0.5547
# Epoch 147/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3508 - accuracy: 0.5759 - val_loss: 1.4162 - val_accuracy: 0.5766
# Epoch 148/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3691 - accuracy: 0.5743 - val_loss: 1.4465 - val_accuracy: 0.5891
# Epoch 149/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3132 - accuracy: 0.5944 - val_loss: 1.4126 - val_accuracy: 0.5766
# Epoch 150/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3465 - accuracy: 0.5783 - val_loss: 1.4551 - val_accuracy: 0.5656
# Epoch 151/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2893 - accuracy: 0.5870 - val_loss: 1.4272 - val_accuracy: 0.5719
# Epoch 152/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3197 - accuracy: 0.5905 - val_loss: 1.4829 - val_accuracy: 0.5531
# Epoch 153/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3099 - accuracy: 0.5888 - val_loss: 1.4558 - val_accuracy: 0.5766
# Epoch 154/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2863 - accuracy: 0.6010 - val_loss: 1.3826 - val_accuracy: 0.5906
# Epoch 155/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2887 - accuracy: 0.5974 - val_loss: 1.4867 - val_accuracy: 0.5797
# Epoch 156/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3066 - accuracy: 0.5837 - val_loss: 1.3495 - val_accuracy: 0.6125
# Epoch 157/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2854 - accuracy: 0.5965 - val_loss: 1.4174 - val_accuracy: 0.5813
# Epoch 158/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2934 - accuracy: 0.5945 - val_loss: 1.3466 - val_accuracy: 0.5813
# Epoch 159/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2839 - accuracy: 0.5939 - val_loss: 1.3725 - val_accuracy: 0.5875
# Epoch 160/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3002 - accuracy: 0.5863 - val_loss: 1.3824 - val_accuracy: 0.5906
# Epoch 161/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3181 - accuracy: 0.5896 - val_loss: 1.4327 - val_accuracy: 0.5719
# Epoch 162/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2573 - accuracy: 0.6059 - val_loss: 1.4091 - val_accuracy: 0.5922
# Epoch 163/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2629 - accuracy: 0.6007 - val_loss: 1.3892 - val_accuracy: 0.5906
# Epoch 164/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2888 - accuracy: 0.5890 - val_loss: 1.3322 - val_accuracy: 0.5953
# Epoch 165/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.3088 - accuracy: 0.5908 - val_loss: 1.3643 - val_accuracy: 0.5781
# Epoch 166/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2462 - accuracy: 0.6042 - val_loss: 1.4009 - val_accuracy: 0.5828
# Epoch 167/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2427 - accuracy: 0.6108 - val_loss: 1.3653 - val_accuracy: 0.6062
# Epoch 168/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2523 - accuracy: 0.6041 - val_loss: 1.5276 - val_accuracy: 0.5641
# Epoch 169/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1977 - accuracy: 0.6223 - val_loss: 1.3630 - val_accuracy: 0.6078
# Epoch 170/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2224 - accuracy: 0.6125 - val_loss: 1.4427 - val_accuracy: 0.5688
# Epoch 171/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2049 - accuracy: 0.6261 - val_loss: 1.3707 - val_accuracy: 0.5688
# Epoch 172/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2522 - accuracy: 0.6091 - val_loss: 1.3735 - val_accuracy: 0.6016
# Epoch 173/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1842 - accuracy: 0.6185 - val_loss: 1.3413 - val_accuracy: 0.6062
# Epoch 174/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2393 - accuracy: 0.6078 - val_loss: 1.3194 - val_accuracy: 0.6078
# Epoch 175/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2117 - accuracy: 0.6199 - val_loss: 1.4061 - val_accuracy: 0.6016
# Epoch 176/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2104 - accuracy: 0.6179 - val_loss: 1.3350 - val_accuracy: 0.6141
# Epoch 177/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2328 - accuracy: 0.6074 - val_loss: 1.3581 - val_accuracy: 0.6047
# Epoch 178/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2436 - accuracy: 0.6013 - val_loss: 1.3842 - val_accuracy: 0.6047
# Epoch 179/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1612 - accuracy: 0.6412 - val_loss: 1.3887 - val_accuracy: 0.5969
# Epoch 180/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1864 - accuracy: 0.6292 - val_loss: 1.3712 - val_accuracy: 0.5813
# Epoch 181/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1778 - accuracy: 0.6307 - val_loss: 1.4175 - val_accuracy: 0.5953
# Epoch 182/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1865 - accuracy: 0.6225 - val_loss: 1.3172 - val_accuracy: 0.6125
# Epoch 183/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1632 - accuracy: 0.6330 - val_loss: 1.4349 - val_accuracy: 0.5688
# Epoch 184/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.2281 - accuracy: 0.6208 - val_loss: 1.2981 - val_accuracy: 0.5781
# Epoch 185/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1759 - accuracy: 0.6267 - val_loss: 1.3381 - val_accuracy: 0.6062
# Epoch 186/250
# 50/50 [==============================] - 1s 13ms/step - loss: 1.1682 - accuracy: 0.6356 - val_loss: 1.3497 - val_accuracy: 0.5938
# Epoch 187/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1638 - accuracy: 0.6345 - val_loss: 1.3745 - val_accuracy: 0.5938
# Epoch 188/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1968 - accuracy: 0.6210 - val_loss: 1.3245 - val_accuracy: 0.6062
# Epoch 189/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1551 - accuracy: 0.6332 - val_loss: 1.2788 - val_accuracy: 0.6172
# Epoch 190/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1351 - accuracy: 0.6391 - val_loss: 1.3496 - val_accuracy: 0.6062
# Epoch 191/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1630 - accuracy: 0.6243 - val_loss: 1.4140 - val_accuracy: 0.6062
# Epoch 192/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1680 - accuracy: 0.6275 - val_loss: 1.3329 - val_accuracy: 0.5984
# Epoch 193/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1939 - accuracy: 0.6314 - val_loss: 1.3629 - val_accuracy: 0.6000
# Epoch 194/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1324 - accuracy: 0.6410 - val_loss: 1.3143 - val_accuracy: 0.6141
# Epoch 195/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1182 - accuracy: 0.6497 - val_loss: 1.3299 - val_accuracy: 0.6203
# Epoch 196/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1457 - accuracy: 0.6396 - val_loss: 1.3608 - val_accuracy: 0.6109
# Epoch 197/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1032 - accuracy: 0.6546 - val_loss: 1.4192 - val_accuracy: 0.5906
# Epoch 198/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1355 - accuracy: 0.6463 - val_loss: 1.3360 - val_accuracy: 0.6094
# Epoch 199/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1328 - accuracy: 0.6340 - val_loss: 1.3586 - val_accuracy: 0.5922
# Epoch 200/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0923 - accuracy: 0.6567 - val_loss: 1.3853 - val_accuracy: 0.5969
# Epoch 201/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1388 - accuracy: 0.6322 - val_loss: 1.3226 - val_accuracy: 0.6172
# Epoch 202/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1250 - accuracy: 0.6414 - val_loss: 1.3205 - val_accuracy: 0.6266
# Epoch 203/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1120 - accuracy: 0.6536 - val_loss: 1.3727 - val_accuracy: 0.6047
# Epoch 204/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1012 - accuracy: 0.6531 - val_loss: 1.3317 - val_accuracy: 0.5953
# Epoch 205/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0943 - accuracy: 0.6493 - val_loss: 1.3373 - val_accuracy: 0.6156
# Epoch 206/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.1039 - accuracy: 0.6402 - val_loss: 1.4046 - val_accuracy: 0.5906
# Epoch 207/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0715 - accuracy: 0.6618 - val_loss: 1.2489 - val_accuracy: 0.6234
# Epoch 208/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0815 - accuracy: 0.6629 - val_loss: 1.3226 - val_accuracy: 0.6234
# Epoch 209/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0944 - accuracy: 0.6532 - val_loss: 1.2734 - val_accuracy: 0.6281
# Epoch 210/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0733 - accuracy: 0.6556 - val_loss: 1.3474 - val_accuracy: 0.6109
# Epoch 211/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0915 - accuracy: 0.6552 - val_loss: 1.3537 - val_accuracy: 0.5875
# Epoch 212/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0929 - accuracy: 0.6452 - val_loss: 1.3711 - val_accuracy: 0.5859
# Epoch 213/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0983 - accuracy: 0.6506 - val_loss: 1.2690 - val_accuracy: 0.6313
# Epoch 214/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0982 - accuracy: 0.6509 - val_loss: 1.4118 - val_accuracy: 0.5906
# Epoch 215/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0858 - accuracy: 0.6646 - val_loss: 1.2548 - val_accuracy: 0.6375
# Epoch 216/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0743 - accuracy: 0.6621 - val_loss: 1.2769 - val_accuracy: 0.6359
# Epoch 217/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0565 - accuracy: 0.6534 - val_loss: 1.2742 - val_accuracy: 0.6266
# Epoch 218/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0695 - accuracy: 0.6623 - val_loss: 1.2633 - val_accuracy: 0.6187
# Epoch 219/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0423 - accuracy: 0.6643 - val_loss: 1.3433 - val_accuracy: 0.6031
# Epoch 220/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0628 - accuracy: 0.6577 - val_loss: 1.3730 - val_accuracy: 0.5953
# Epoch 221/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0645 - accuracy: 0.6659 - val_loss: 1.2848 - val_accuracy: 0.6094
# Epoch 222/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0628 - accuracy: 0.6630 - val_loss: 1.3019 - val_accuracy: 0.6281
# Epoch 223/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0376 - accuracy: 0.6703 - val_loss: 1.3583 - val_accuracy: 0.6109
# Epoch 224/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0438 - accuracy: 0.6617 - val_loss: 1.2634 - val_accuracy: 0.6359
# Epoch 225/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0440 - accuracy: 0.6652 - val_loss: 1.3088 - val_accuracy: 0.6125
# Epoch 226/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0531 - accuracy: 0.6691 - val_loss: 1.1930 - val_accuracy: 0.6187
# Epoch 227/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0440 - accuracy: 0.6596 - val_loss: 1.2758 - val_accuracy: 0.6344
# Epoch 228/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0555 - accuracy: 0.6600 - val_loss: 1.2665 - val_accuracy: 0.6344
# Epoch 229/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0406 - accuracy: 0.6688 - val_loss: 1.2771 - val_accuracy: 0.6141
# Epoch 230/250
# 50/50 [==============================] - 1s 14ms/step - loss: 0.9955 - accuracy: 0.6810 - val_loss: 1.1591 - val_accuracy: 0.6547
# Epoch 231/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0188 - accuracy: 0.6665 - val_loss: 1.1930 - val_accuracy: 0.6516
# Epoch 232/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0303 - accuracy: 0.6695 - val_loss: 1.3579 - val_accuracy: 0.5859
# Epoch 233/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0283 - accuracy: 0.6707 - val_loss: 1.2341 - val_accuracy: 0.6469
# Epoch 234/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0299 - accuracy: 0.6750 - val_loss: 1.3628 - val_accuracy: 0.6109
# Epoch 235/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0048 - accuracy: 0.6825 - val_loss: 1.3245 - val_accuracy: 0.6141
# Epoch 236/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0019 - accuracy: 0.6807 - val_loss: 1.3133 - val_accuracy: 0.6281
# Epoch 237/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0305 - accuracy: 0.6707 - val_loss: 1.2586 - val_accuracy: 0.6344
# Epoch 238/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0402 - accuracy: 0.6674 - val_loss: 1.3111 - val_accuracy: 0.6141
# Epoch 239/250
# 50/50 [==============================] - 1s 14ms/step - loss: 0.9956 - accuracy: 0.6770 - val_loss: 1.2412 - val_accuracy: 0.6609
# Epoch 240/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0140 - accuracy: 0.6761 - val_loss: 1.2333 - val_accuracy: 0.6344
# Epoch 241/250
# 50/50 [==============================] - 1s 14ms/step - loss: 0.9954 - accuracy: 0.6784 - val_loss: 1.2544 - val_accuracy: 0.6203
# Epoch 242/250
# 50/50 [==============================] - 1s 14ms/step - loss: 0.9882 - accuracy: 0.6885 - val_loss: 1.3240 - val_accuracy: 0.6016
# Epoch 243/250
# 50/50 [==============================] - 1s 14ms/step - loss: 0.9663 - accuracy: 0.6890 - val_loss: 1.3014 - val_accuracy: 0.6344
# Epoch 244/250
# 50/50 [==============================] - 1s 14ms/step - loss: 0.9778 - accuracy: 0.6802 - val_loss: 1.3429 - val_accuracy: 0.6078
# Epoch 245/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0028 - accuracy: 0.6713 - val_loss: 1.2163 - val_accuracy: 0.6313
# Epoch 246/250
# 50/50 [==============================] - 1s 14ms/step - loss: 0.9799 - accuracy: 0.6882 - val_loss: 1.3037 - val_accuracy: 0.6156
# Epoch 247/250
# 50/50 [==============================] - 1s 14ms/step - loss: 0.9911 - accuracy: 0.6778 - val_loss: 1.2286 - val_accuracy: 0.6391
# Epoch 248/250
# 50/50 [==============================] - 1s 14ms/step - loss: 0.9419 - accuracy: 0.6928 - val_loss: 1.2154 - val_accuracy: 0.6281
# Epoch 249/250
# 50/50 [==============================] - 1s 14ms/step - loss: 1.0195 - accuracy: 0.6728 - val_loss: 1.2852 - val_accuracy: 0.6219
# Epoch 250/250
# 50/50 [==============================] - 1s 14ms/step - loss: 0.9866 - accuracy: 0.6801 - val_loss: 1.2421 - val_accuracy: 0.6516
# Test set evaluation metrics
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2851 - accuracy: 0.6003
# loss: 1.29
# accuracy: 0.60

# %% [markdown]
# ### Μεταφορά μάθησης: VGG16

# %%
# transfer learning: VGG16 trained on ImageNet without the top layer

def init_VGG16_model(summary):
  vgg_model=tf.keras.applications.VGG16(input_shape=(32,32,3), include_top=False, weights='imagenet')
  
  VGG16_MODEL=vgg_model.layers[0](vgg_model)

  # unfreeze conv layers
  #prosthese 2 entoles
  VGG16_MODEL.trainable=True
  
  dropout_layer = tf.keras.layers.Dropout(rate = 0.5)
  global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

  # add top layer for CIFAR100 classification
  prediction_layer = tf.keras.layers.Dense(len(CIFAR100_LABELS_LIST),activation='softmax')
  model = tf.keras.Sequential([VGG16_MODEL, dropout_layer, global_average_layer, prediction_layer])
  model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.0001), loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=["accuracy"])
  if summary: 
    model.summary()
  return model

# %%
VGG16_MODEL = init_VGG16_model(True)
VGG16_MODEL_history = train_model(VGG16_MODEL, 25, 40, 10)

model_report(VGG16_MODEL, VGG16_MODEL_history, 30)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 1, 1, 512)         14714688
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 1, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               51300
# =================================================================
# Total params: 14,765,988
# Trainable params: 14,765,988
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 40/40 [==============================] - 4s 65ms/step - loss: 4.0683 - accuracy: 0.0755 - val_loss: 2.2453 - val_accuracy: 0.3398
# Epoch 2/25
# 40/40 [==============================] - 2s 61ms/step - loss: 2.4129 - accuracy: 0.3300 - val_loss: 1.4511 - val_accuracy: 0.5734
# Epoch 3/25
# 40/40 [==============================] - 2s 60ms/step - loss: 1.6659 - accuracy: 0.5131 - val_loss: 1.2510 - val_accuracy: 0.6219
# Epoch 4/25
# 40/40 [==============================] - 2s 61ms/step - loss: 1.3542 - accuracy: 0.5963 - val_loss: 1.0664 - val_accuracy: 0.6617
# Epoch 5/25
# 40/40 [==============================] - 2s 61ms/step - loss: 1.1392 - accuracy: 0.6545 - val_loss: 1.0407 - val_accuracy: 0.6766
# Epoch 6/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.8555 - accuracy: 0.7278 - val_loss: 1.0126 - val_accuracy: 0.6898
# Epoch 7/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.8566 - accuracy: 0.7275 - val_loss: 0.9854 - val_accuracy: 0.7125
# Epoch 8/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.6169 - accuracy: 0.8083 - val_loss: 0.9337 - val_accuracy: 0.7195
# Epoch 9/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.5871 - accuracy: 0.8184 - val_loss: 0.8974 - val_accuracy: 0.7453
# Epoch 10/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.5181 - accuracy: 0.8423 - val_loss: 0.9683 - val_accuracy: 0.7391
# Epoch 11/25
# 40/40 [==============================] - 2s 60ms/step - loss: 0.3101 - accuracy: 0.8981 - val_loss: 0.9233 - val_accuracy: 0.7570
# Epoch 12/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.3660 - accuracy: 0.8896 - val_loss: 1.0320 - val_accuracy: 0.7336
# Epoch 13/25
# 40/40 [==============================] - 2s 60ms/step - loss: 0.2696 - accuracy: 0.9093 - val_loss: 0.9900 - val_accuracy: 0.7406
# Epoch 14/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.2556 - accuracy: 0.9142 - val_loss: 1.0687 - val_accuracy: 0.7336
# Epoch 15/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.1362 - accuracy: 0.9528 - val_loss: 0.9916 - val_accuracy: 0.7648
# Epoch 16/25
# 40/40 [==============================] - 2s 60ms/step - loss: 0.1152 - accuracy: 0.9629 - val_loss: 1.0113 - val_accuracy: 0.7742
# Epoch 17/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.1083 - accuracy: 0.9629 - val_loss: 1.0712 - val_accuracy: 0.7492
# Epoch 18/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.1074 - accuracy: 0.9663 - val_loss: 1.2039 - val_accuracy: 0.7492
# Epoch 19/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.0654 - accuracy: 0.9826 - val_loss: 1.0227 - val_accuracy: 0.7727
# Epoch 20/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.0718 - accuracy: 0.9773 - val_loss: 1.2092 - val_accuracy: 0.7367
# Epoch 21/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.0569 - accuracy: 0.9797 - val_loss: 1.2314 - val_accuracy: 0.7570
# Epoch 22/25
# 40/40 [==============================] - 2s 62ms/step - loss: 0.0539 - accuracy: 0.9836 - val_loss: 1.2593 - val_accuracy: 0.7453
# Epoch 23/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.0509 - accuracy: 0.9820 - val_loss: 1.3351 - val_accuracy: 0.7422
# Epoch 24/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.0651 - accuracy: 0.9809 - val_loss: 1.2442 - val_accuracy: 0.7344
# Epoch 25/25
# 40/40 [==============================] - 2s 61ms/step - loss: 0.0737 - accuracy: 0.9791 - val_loss: 1.2825 - val_accuracy: 0.7242
# Test set evaluation metrics
# 30/30 [==============================] - 1s 15ms/step - loss: 1.2862 - accuracy: 0.7411
# loss: 1.29
# accuracy: 0.74

# %% [markdown]
# # Μέθοδος ResNet

# %%
def init_resnet_model(summary):
    resnet_MODEL = tf.keras.applications.resnet.ResNet50(input_shape=(img_rows, img_cols, img_channels),
                                                         include_top=False,
                                                         weights='imagenet')
    # unfreeze conv layers
    resnet_MODEL.trainable = True
    dropout_layer = tf.keras.layers.Dropout(rate=0.7)
    dropout_layer.trainable = True
    global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
    global_average_layer.trainable = True
    
    # add top layer for CIFAR100 classification
    prediction_layer = tf.keras.layers.Dense(len(CIFAR100_LABELS_LIST),activation='softmax')
    model = tf.keras.Sequential([resnet_MODEL, dropout_layer, global_average_layer, prediction_layer])
    model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.001),
                  loss=tf.keras.losses.sparse_categorical_crossentropy,
                  metrics=["accuracy"])
    if summary: model.summary()
    return model

resnet_MODEL = init_resnet_model(summary = True)
resnet_MODEL_history = train_model(resnet_MODEL, 100, 40, 10) 
model_report(resnet_MODEL, resnet_MODEL_history, 30)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 1, 1, 2048)        23587712
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1, 1, 2048)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               204900
# =================================================================
# Total params: 23,792,612
# Trainable params: 23,739,492
# Non-trainable params: 53,120
# _________________________________________________________________
# Epoch 1/100
# 40/40 [==============================] - 9s 93ms/step - loss: 5.9489 - accuracy: 0.0948 - val_loss: 176.0182 - val_accuracy: 0.0625
# Epoch 2/100
# 40/40 [==============================] - 3s 72ms/step - loss: 3.2443 - accuracy: 0.2592 - val_loss: 1049.8174 - val_accuracy: 0.0562
# Epoch 3/100
# 40/40 [==============================] - 3s 72ms/step - loss: 2.4113 - accuracy: 0.3450 - val_loss: 8.6237 - val_accuracy: 0.0453
# Epoch 4/100
# 40/40 [==============================] - 3s 72ms/step - loss: 2.0524 - accuracy: 0.4629 - val_loss: 5.0294 - val_accuracy: 0.0500
# Epoch 5/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.7057 - accuracy: 0.5182 - val_loss: 10.1252 - val_accuracy: 0.0555
# Epoch 6/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.4632 - accuracy: 0.5816 - val_loss: 5.5968 - val_accuracy: 0.0547
# Epoch 7/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.2316 - accuracy: 0.6497 - val_loss: 3.4041 - val_accuracy: 0.0500
# Epoch 8/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.3742 - accuracy: 0.6492 - val_loss: 3.4075 - val_accuracy: 0.0437
# Epoch 9/100
# 40/40 [==============================] - 3s 73ms/step - loss: 2.3739 - accuracy: 0.4424 - val_loss: 26.8389 - val_accuracy: 0.0477
# Epoch 10/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.8472 - accuracy: 0.5052 - val_loss: 3.3515 - val_accuracy: 0.0484
# Epoch 11/100
# 40/40 [==============================] - 3s 73ms/step - loss: 2.2620 - accuracy: 0.4267 - val_loss: 487.9512 - val_accuracy: 0.0586
# Epoch 12/100
# 40/40 [==============================] - 3s 73ms/step - loss: 2.0708 - accuracy: 0.4308 - val_loss: 20.8680 - val_accuracy: 0.0578
# Epoch 13/100
# 40/40 [==============================] - 3s 73ms/step - loss: 2.5165 - accuracy: 0.4396 - val_loss: 7.7756 - val_accuracy: 0.0641
# Epoch 14/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.9161 - accuracy: 0.4898 - val_loss: 6.5441 - val_accuracy: 0.0797
# Epoch 15/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.6610 - accuracy: 0.5414 - val_loss: 4.5181 - val_accuracy: 0.0992
# Epoch 16/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.3525 - accuracy: 0.6183 - val_loss: 9.9845 - val_accuracy: 0.0461
# Epoch 17/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.8058 - accuracy: 0.5749 - val_loss: 4.6416 - val_accuracy: 0.0727
# Epoch 18/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.5797 - accuracy: 0.5921 - val_loss: 3.4057 - val_accuracy: 0.1141
# Epoch 19/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.3861 - accuracy: 0.6213 - val_loss: 3.7200 - val_accuracy: 0.1484
# Epoch 20/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.4456 - accuracy: 0.6554 - val_loss: 2.7378 - val_accuracy: 0.2211
# Epoch 21/100
# 40/40 [==============================] - 3s 72ms/step - loss: 1.3112 - accuracy: 0.6768 - val_loss: 3.3082 - val_accuracy: 0.2031
# Epoch 22/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.2984 - accuracy: 0.6625 - val_loss: 2.6498 - val_accuracy: 0.3297
# Epoch 23/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.8605 - accuracy: 0.7359 - val_loss: 2.7803 - val_accuracy: 0.3438
# Epoch 24/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.7427 - accuracy: 0.7714 - val_loss: 1.9887 - val_accuracy: 0.4805
# Epoch 25/100
# 40/40 [==============================] - 3s 72ms/step - loss: 0.9154 - accuracy: 0.7936 - val_loss: 3.0292 - val_accuracy: 0.3359
# Epoch 26/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.7764 - accuracy: 0.7755 - val_loss: 2.6409 - val_accuracy: 0.4047
# Epoch 27/100
# 40/40 [==============================] - 3s 72ms/step - loss: 0.7202 - accuracy: 0.7948 - val_loss: 2.5814 - val_accuracy: 0.4336
# Epoch 28/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.5926 - accuracy: 0.8439 - val_loss: 1.4685 - val_accuracy: 0.6102
# Epoch 29/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.5859 - accuracy: 0.8457 - val_loss: 1.7810 - val_accuracy: 0.5758
# Epoch 30/100
# 40/40 [==============================] - 3s 72ms/step - loss: 0.7473 - accuracy: 0.8582 - val_loss: 781.0541 - val_accuracy: 0.0437
# Epoch 31/100
# 40/40 [==============================] - 3s 73ms/step - loss: 2.6873 - accuracy: 0.3825 - val_loss: 30.7141 - val_accuracy: 0.0977
# Epoch 32/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.7241 - accuracy: 0.4895 - val_loss: 4.1723 - val_accuracy: 0.2742
# Epoch 33/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.4713 - accuracy: 0.5744 - val_loss: 4.0979 - val_accuracy: 0.2922
# Epoch 34/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.4554 - accuracy: 0.6090 - val_loss: 71.1366 - val_accuracy: 0.3172
# Epoch 35/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.8752 - accuracy: 0.5928 - val_loss: 10.6151 - val_accuracy: 0.2586
# Epoch 36/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.6474 - accuracy: 0.5740 - val_loss: 3.5363 - val_accuracy: 0.3430
# Epoch 37/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.3024 - accuracy: 0.6177 - val_loss: 1.7961 - val_accuracy: 0.5039
# Epoch 38/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.0089 - accuracy: 0.6997 - val_loss: 1.6195 - val_accuracy: 0.5422
# Epoch 39/100
# 40/40 [==============================] - 3s 72ms/step - loss: 0.9275 - accuracy: 0.7278 - val_loss: 2.1561 - val_accuracy: 0.4812
# Epoch 40/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.8858 - accuracy: 0.7508 - val_loss: 1.6429 - val_accuracy: 0.5547
# Epoch 41/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.7347 - accuracy: 0.8137 - val_loss: 1.7757 - val_accuracy: 0.5445
# Epoch 42/100
# 40/40 [==============================] - 3s 72ms/step - loss: 0.7537 - accuracy: 0.7814 - val_loss: 1.8011 - val_accuracy: 0.5625
# Epoch 43/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.9269 - accuracy: 0.7764 - val_loss: 2.8399 - val_accuracy: 0.5016
# Epoch 44/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.1020 - accuracy: 0.7272 - val_loss: 17.7558 - val_accuracy: 0.2195
# Epoch 45/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.6296 - accuracy: 0.6293 - val_loss: 4.2396 - val_accuracy: 0.2828
# Epoch 46/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.2341 - accuracy: 0.6607 - val_loss: 3.2101 - val_accuracy: 0.3844
# Epoch 47/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.1713 - accuracy: 0.6925 - val_loss: 2.4204 - val_accuracy: 0.5156
# Epoch 48/100
# 40/40 [==============================] - 3s 73ms/step - loss: 1.0650 - accuracy: 0.7034 - val_loss: 2.1507 - val_accuracy: 0.4914
# Epoch 49/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.7777 - accuracy: 0.7941 - val_loss: 1.5053 - val_accuracy: 0.6156
# Epoch 50/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.6724 - accuracy: 0.8204 - val_loss: 1.4500 - val_accuracy: 0.6164
# Epoch 51/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.4022 - accuracy: 0.8798 - val_loss: 1.8185 - val_accuracy: 0.5875
# Epoch 52/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.5245 - accuracy: 0.8641 - val_loss: 1.6539 - val_accuracy: 0.6062
# Epoch 53/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.5589 - accuracy: 0.8567 - val_loss: 1.7157 - val_accuracy: 0.5875
# Epoch 54/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.4236 - accuracy: 0.8966 - val_loss: 2.0860 - val_accuracy: 0.5766
# Epoch 55/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.4034 - accuracy: 0.8809 - val_loss: 3.2926 - val_accuracy: 0.4180
# Epoch 56/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.8284 - accuracy: 0.7701 - val_loss: 2.3418 - val_accuracy: 0.5312
# Epoch 57/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.8570 - accuracy: 0.7684 - val_loss: 2.5879 - val_accuracy: 0.4781
# Epoch 58/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.7281 - accuracy: 0.8270 - val_loss: 2.2758 - val_accuracy: 0.5297
# Epoch 59/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.8082 - accuracy: 0.8071 - val_loss: 2.3397 - val_accuracy: 0.5328
# Epoch 60/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.6015 - accuracy: 0.8251 - val_loss: 1.8829 - val_accuracy: 0.5766
# Epoch 61/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.3040 - accuracy: 0.9111 - val_loss: 1.9586 - val_accuracy: 0.6031
# Epoch 62/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.2902 - accuracy: 0.9216 - val_loss: 1.9130 - val_accuracy: 0.6172
# Epoch 63/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.2736 - accuracy: 0.9325 - val_loss: 1.8178 - val_accuracy: 0.6148
# Epoch 64/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1822 - accuracy: 0.9493 - val_loss: 2.0193 - val_accuracy: 0.6203
# Epoch 65/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1738 - accuracy: 0.9454 - val_loss: 2.1357 - val_accuracy: 0.6109
# Epoch 66/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1436 - accuracy: 0.9562 - val_loss: 2.0922 - val_accuracy: 0.6125
# Epoch 67/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1916 - accuracy: 0.9509 - val_loss: 2.2506 - val_accuracy: 0.6117
# Epoch 68/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.3525 - accuracy: 0.9248 - val_loss: 2.5762 - val_accuracy: 0.5555
# Epoch 69/100
# 40/40 [==============================] - 3s 72ms/step - loss: 0.3355 - accuracy: 0.9182 - val_loss: 2.3176 - val_accuracy: 0.5930
# Epoch 70/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.2172 - accuracy: 0.9325 - val_loss: 2.1405 - val_accuracy: 0.6117
# Epoch 71/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1255 - accuracy: 0.9618 - val_loss: 2.6077 - val_accuracy: 0.5594
# Epoch 72/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1245 - accuracy: 0.9606 - val_loss: 2.1927 - val_accuracy: 0.6211
# Epoch 73/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1109 - accuracy: 0.9722 - val_loss: 2.1792 - val_accuracy: 0.6234
# Epoch 74/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1057 - accuracy: 0.9720 - val_loss: 2.4220 - val_accuracy: 0.6180
# Epoch 75/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1113 - accuracy: 0.9654 - val_loss: 2.2760 - val_accuracy: 0.6180
# Epoch 76/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1069 - accuracy: 0.9702 - val_loss: 2.4351 - val_accuracy: 0.6203
# Epoch 77/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1168 - accuracy: 0.9636 - val_loss: 2.4295 - val_accuracy: 0.6164
# Epoch 78/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1098 - accuracy: 0.9696 - val_loss: 2.6936 - val_accuracy: 0.5789
# Epoch 79/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.3016 - accuracy: 0.9341 - val_loss: 2.9071 - val_accuracy: 0.5969
# Epoch 80/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.3627 - accuracy: 0.9165 - val_loss: 2.3732 - val_accuracy: 0.5914
# Epoch 81/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1270 - accuracy: 0.9641 - val_loss: 2.3494 - val_accuracy: 0.6047
# Epoch 82/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.2138 - accuracy: 0.9514 - val_loss: 2.7076 - val_accuracy: 0.5633
# Epoch 83/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.2906 - accuracy: 0.9238 - val_loss: 2.2741 - val_accuracy: 0.6117
# Epoch 84/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.2539 - accuracy: 0.9582 - val_loss: 2.2670 - val_accuracy: 0.5992
# Epoch 85/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.2268 - accuracy: 0.9402 - val_loss: 2.6756 - val_accuracy: 0.5984
# Epoch 86/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1667 - accuracy: 0.9635 - val_loss: 2.2781 - val_accuracy: 0.6016
# Epoch 87/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1108 - accuracy: 0.9691 - val_loss: 2.3033 - val_accuracy: 0.6258
# Epoch 88/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0937 - accuracy: 0.9746 - val_loss: 2.1572 - val_accuracy: 0.6195
# Epoch 89/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1201 - accuracy: 0.9667 - val_loss: 2.5133 - val_accuracy: 0.5977
# Epoch 90/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1401 - accuracy: 0.9649 - val_loss: 2.4701 - val_accuracy: 0.6148
# Epoch 91/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1226 - accuracy: 0.9770 - val_loss: 2.9206 - val_accuracy: 0.5180
# Epoch 92/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.4905 - accuracy: 0.9099 - val_loss: 3.2772 - val_accuracy: 0.5016
# Epoch 93/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.3810 - accuracy: 0.8999 - val_loss: 2.4043 - val_accuracy: 0.5727
# Epoch 94/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1927 - accuracy: 0.9519 - val_loss: 3.4549 - val_accuracy: 0.4977
# Epoch 95/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.3569 - accuracy: 0.8983 - val_loss: 2.2669 - val_accuracy: 0.6016
# Epoch 96/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.2058 - accuracy: 0.9593 - val_loss: 2.1321 - val_accuracy: 0.6398
# Epoch 97/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1290 - accuracy: 0.9652 - val_loss: 2.5154 - val_accuracy: 0.5859
# Epoch 98/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.3076 - accuracy: 0.9234 - val_loss: 2.1167 - val_accuracy: 0.6156
# Epoch 99/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1496 - accuracy: 0.9582 - val_loss: 2.4837 - val_accuracy: 0.6000
# Epoch 100/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.1875 - accuracy: 0.9492 - val_loss: 2.3281 - val_accuracy: 0.6078
# Test set evaluation metrics
# 30/30 [==============================] - 1s 17ms/step - loss: 2.2176 - accuracy: 0.6141
# loss: 2.22
# accuracy: 0.61

# %% [markdown]
# # Μέθοδος DenseNet

# %%
def init_densenet_model(summary):
    densenet_MODEL=tf.keras.applications.densenet.DenseNet121(input_shape=(img_rows, img_cols, img_channels),
                                                              include_top=False,
                                                              weights='imagenet')
    # unfreeze conv layers
    densenet_MODEL.trainable = True
    dropout_layer = tf.keras.layers.Dropout(rate=0.5)
    dropout_layer.trainable = True
    global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
    global_average_layer.trainable = True
    
    # add top layer for CIFAR100 classification
    prediction_layer = tf.keras.layers.Dense(len(CIFAR100_LABELS_LIST),activation='softmax')
    model = tf.keras.Sequential([densenet_MODEL, dropout_layer, global_average_layer, prediction_layer])

    model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.0002),
                  loss=tf.keras.losses.sparse_categorical_crossentropy,
                  metrics=["accuracy"])
    if summary: model.summary()
    return model

densenet_MODEL = init_densenet_model(summary = True)
densenet_MODEL_history = train_model(densenet_MODEL, 20, 40, 10) # re-train for less epochs
model_report(densenet_MODEL, densenet_MODEL_history, 30)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Functional)     (None, 1, 1, 1024)        7037504
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1, 1, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               102500
# =================================================================
# Total params: 7,140,004
# Trainable params: 7,056,356
# Non-trainable params: 83,648
# _________________________________________________________________
# Epoch 1/20
# 40/40 [==============================] - 14s 94ms/step - loss: 4.8073 - accuracy: 0.0727 - val_loss: 3.4724 - val_accuracy: 0.1773
# Epoch 2/20
# 40/40 [==============================] - 2s 56ms/step - loss: 2.4696 - accuracy: 0.2943 - val_loss: 2.7974 - val_accuracy: 0.3352
# Epoch 3/20
# 40/40 [==============================] - 2s 56ms/step - loss: 1.6468 - accuracy: 0.5091 - val_loss: 2.2579 - val_accuracy: 0.5063
# Epoch 4/20
# 40/40 [==============================] - 2s 56ms/step - loss: 1.2414 - accuracy: 0.6345 - val_loss: 1.8742 - val_accuracy: 0.5742
# Epoch 5/20
# 40/40 [==============================] - 2s 56ms/step - loss: 0.9704 - accuracy: 0.7093 - val_loss: 1.4430 - val_accuracy: 0.6570
# Epoch 6/20
# 40/40 [==============================] - 2s 56ms/step - loss: 0.6177 - accuracy: 0.8228 - val_loss: 1.2753 - val_accuracy: 0.6578
# Epoch 7/20
# 40/40 [==============================] - 2s 56ms/step - loss: 0.5590 - accuracy: 0.8281 - val_loss: 1.0546 - val_accuracy: 0.7031
# Epoch 8/20
# 40/40 [==============================] - 2s 57ms/step - loss: 0.3392 - accuracy: 0.8976 - val_loss: 0.9894 - val_accuracy: 0.7047
# Epoch 9/20
# 40/40 [==============================] - 2s 57ms/step - loss: 0.3219 - accuracy: 0.8979 - val_loss: 0.9644 - val_accuracy: 0.7164
# Epoch 10/20
# 40/40 [==============================] - 2s 57ms/step - loss: 0.2138 - accuracy: 0.9361 - val_loss: 0.9191 - val_accuracy: 0.7195
# Epoch 11/20
# 40/40 [==============================] - 2s 57ms/step - loss: 0.1258 - accuracy: 0.9638 - val_loss: 1.0534 - val_accuracy: 0.7039
# Epoch 12/20
# 40/40 [==============================] - 2s 57ms/step - loss: 0.1430 - accuracy: 0.9614 - val_loss: 1.0214 - val_accuracy: 0.7180
# Epoch 13/20
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0989 - accuracy: 0.9752 - val_loss: 1.0317 - val_accuracy: 0.7211
# Epoch 14/20
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0946 - accuracy: 0.9720 - val_loss: 1.0227 - val_accuracy: 0.7414
# Epoch 15/20
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0777 - accuracy: 0.9754 - val_loss: 1.0439 - val_accuracy: 0.7312
# Epoch 16/20
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0522 - accuracy: 0.9875 - val_loss: 1.0322 - val_accuracy: 0.7430
# Epoch 17/20
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0477 - accuracy: 0.9880 - val_loss: 1.0818 - val_accuracy: 0.7414
# Epoch 18/20
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0414 - accuracy: 0.9911 - val_loss: 1.1045 - val_accuracy: 0.7352
# Epoch 19/20
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0565 - accuracy: 0.9847 - val_loss: 1.1071 - val_accuracy: 0.7539
# Epoch 20/20
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0496 - accuracy: 0.9869 - val_loss: 1.2647 - val_accuracy: 0.7250
# Test set evaluation metrics
# 30/30 [==============================] - 1s 17ms/step - loss: 1.2369 - accuracy: 0.7167
# loss: 1.24
# accuracy: 0.72

# %% [markdown]
# # Βελτίωση της επίδοσης με πειράματα
#
# Καλείστε να βελτιώσετε τα αποτελέσματα ταξινόμησης στο CIFAR-100 και να βγάλατε συμπεράσματα, σύμφωνα με όσα ζητούνται σε σχέση με την αναφορά παράδοσης.

# %% [markdown]
# ## Δοκιμές διαφορετικών μοντέλων
#
# Μπορείτε είτε να δοκιμάσετε μοντέλα "from scratch", όπου ορίζετε την αρχιτεκτονική του δικτύου όπως θέλετε, είτε να χρησιμοποιήσετε μεταφορά μάθησης.

# %% [markdown]
# ### Μοντέλα "from scratch"
#
# Μπορείτε να τροποποιήσετε/αλλάξετε το αρχικό μικρό συνελικτικό δίκτυο του παραδείγματος. Μπορείτε να συμβουλευτείτε
# - τη [βιβλιογραφία απο το leaderboard του CIFAR-100](https://benchmarks.ai/cifar-100) για αρχιτεκτονικές και παραμέτρους των δικτύων
# - ή/και να πάρετε ιδέες [από σχετική αναζήτηση στο Google Scholar](https://scholar.google.gr/scholar?hl=en&as_sdt=0%2C5&q=cifar+100+cnn&oq=cifa)

# %% [markdown]
# ### Μεταφορά μάθησης
#
# Εναλλακτικά, μπορείτε να χρησιμοποιήσετ τη [μεταφορά μάθησης του tf2](https://www.tensorflow.org/tutorials/images/transfer_learning). Σε αντίθεση με τα μοντέλα "from scratch" η μεταφορά μάθησης μας επιστρέφει έτοιμα μοντέλα με προκαθορισμένη αρχιτεκτονική στην οποία μπορούμε γενικά μόνο να προσθέσουμε επίπεδα, τα οποία συνήθως περιορίζοντα σε πλήρως διασυνδεδεμένα επίπεδα που εξειδικεύονται στο συγκεκριμένο task ταξινόμησης που έχουμε να επιτελέσουμε.

# %% [markdown]
# #### Εκπαίδευση βαρών
#
# Ταυτόχρονα με την αρχιτεκτονική, στη μεταφορά μάθησης εισάγουμε και τη γνώση που έχει αποκτήσει το μοντέλο, δηλαδή τις τιμές των βαρών του όπως έχουν προκύψει μετά από εκπαίδευση συνήθως στο (τεράστιο) ImageNet. Οταν εισάγουμε ένα μοντέλο με μεταφορά μάθησης έχουμε τρεις επιλογές για την εκπαίδευση:
# - να παγώσουμε τη συνελικτική βάση και να εκπαιδεύσουμε την κεφαλή ταξινόμησης (classification head). Αυτό αντιστοιχεί στο να χρησιμοποιήσουμε τη συνελικτική βάση για εξαγωγή χαρακτηριστικών (feature extraction), σημαία trainable = False.
# - να συνεχίσουμε να εκπαιδεύουμε όλα τα επίπεδα του δικτύου, σημαία trainable = True.
# - να εκπαιδευτεί μόνο ένα ποσοστό των επιπέδων, εβρισκόμενο προς την έξοδο του δικτύου. Οι σημαίες trainable εδώ θα πρέπει να οριστούν ανά επίπεδο.

# %% [markdown]
# #### Διαθέσιμα μοντέλα για μεταφορά μάθησης στο tf2
#
# 1. tf.keras.applications. Ο πιο απλός τρόπος για να κάνουμε μεταφορά μάθησης στο tf2 είναι μέσω του [tf.keras.applications](https://www.tensorflow.org/api_docs/python/tf/keras/applications) που παρέχει προεκπαιδευμένα μοντέλα από το Keras και συγκεκριμένα τα δίκτυα: DenseNet, Inception-ResNet V2, Inception V3, MobileNet v1, MobileNet v2, NASNet-A, ResNet, ResNet v2, VGG16, VGG19 και Xception V1. Η εισαγωγή των μοντέλων γίνεται παρόμοια με αυτή που δείξαμε παραπάνω για το VGG16.
#
# 2. TensorFlow Hub. Μπορείτε επίσης να χρησιμοποιήσετε μοντέλα τα οποία είναι διαθέσιμα στο αποθετήριο [TensoFlow Hub](https://tfhub.dev/s?fine-tunable=yes&module-type=image-augmentation,image-classification,image-feature-vector,image-generator,image-object-detection,image-others,image-style-transfer,image-rnn-agent&tf-version=tf2) το οποίο περιλαμβάνει πάνω από 100 προεκπαιδευμένα μοντέλα.
#
# 3. Αποθηκευμένα μοντέλα απο τρίτες πηγές. Μπορείτε επίσης να κάνετε μεταφορά μάθησης από τρίτες πηγές, είτε του συνόλου του νευρωνικού, αρχιτεκτονικής και βαρών, είτε μόνο της αρχιτεκτονικής ή των βαρών. Το μοντέλο θα πρέπει να έχει αποθηκευθεί σε ένα από τα δύο φορμάτ, Keras HDF5 format (.h5 ή .keras) ή στο SavedModel format που αναφέραμε στην εισαγωγή. Τα βάρη μπορούν να εισαχθούν και μόνα τους ως Checkpoints. Για περισσότερα, διαβάστε σχετικά τα λήμματα ["Save and load models"](https://www.tensorflow.org/tutorials/keras/save_and_load), ["Save and serialize"](https://www.tensorflow.org/guide/keras/save_and_serialize), ["Using the SavedModel format"](https://www.tensorflow.org/guide/saved_model) και δείτε για παράδειγμα πως μπορούμε να κάνουμε μεταφορά μάθησης από τα state-of-the-art EfficientNets ([1](https://www.dlology.com/blog/transfer-learning-with-efficientnet/), [2](https://github.com/tensorflow/tpu/tree/master/models/official/efficientnethttps://)).
#
# Σημειώστε ότι πολλά μοντέλα απαιτούν μεγαλύτερες διαστάσεις στην είσοδο από αυτές του CIFAR-100 και κατά συνέπεια τα δεδομένα πρέπει να [μετασχηματιστούν](https://www.tensorflow.org/api_docs/python/tf/image/resize). Προσέξτε ωστόσο τις απαιτήσεις σε μνήμη όταν αυτοί οι μετασχηματισμοί γίνονται απευθείας σε μεταβλητές (βλ. πιο κάτω "Διαχείριση μνήμης").

# %% [markdown]
# ### Επαύξηση δεδομένων
#
# Μια τεχνική που μπορεί να σας δώσει καλά αποτελέσματα είναι η επάυξηση δεδομένων (data augmentation). Η επαύξηση δεδομένων επιτρέπει να δημιουργήσουμε μεγαλύτερη ποικιλία στα δεδομένα εφαρμόζοντας τυχαίους αλλά ρεαλιστικούς μετασχηματισμούς στις εικόνες, όπως πχ η περιστροφη.
#
# Μπορούμε να κάνουμε data augmetation με δύο τρόπους: με επίπεδα προεπεξεργασίας του Keras, ή με χρήση του tf.image. Δείτε [εδώ](https://www.tensorflow.org/tutorials/images/data_augmentation) σχετικά από το documentation του TensorFlow και [εδώ](https://stepup.ai/train_data_augmentation_keras/) ένα πρακτικό παράδειγμα στο CIFAR-10.

# %% [markdown]
# ## Παρατηρήσεις ως προς τη βελτιστοποίηση

# %% [markdown]
# ### Διαχείριση μνήμης (TFRecord)
#
# Η φόρτωση δεδομένων με τον τρόπο που το κάναμε παραπάνω στο απλό παράδειγμα υλοποίησης είναι πολύ βολική αλλά δεν είναι καθόλου αποτελεσματική ως προς τη διαχείριση της μνήμης. Συγκεκριμένα, με τον τρόπο αυτό, τα δεδομένα αποθηκεύονται απευθείας σε μεταβλητές, οι οποίες όλες μαζί καταλαμβάνουν τη RAM της CPU ή της GPU, κάτι που κάνει αδύνατη τη διαχείριση μεγάλων datasets ή τον μεταχηματισμό των δεδομένων όπως όταν κάνουμε αύξηση δεδομένων (data augmentation).
#
# Για να παρακαμφθεί αυτό το πρόβλημα, υπάρχει η δυνατότητα της σειριοποίησης των δεδομένων (serialization) και της αποθήκευσής τους σε αρχεία μεσαίου μεγέθους (κάποιων MB) τα οποία μπορούνα να αναγνωστούν γραμμικά. Το φορμάτ TFRecord είναι ένα φορμάτ που επιτρέπει την αποθήκευση σειράς δυαδικών εγγραφών. Διαβάστε τα σχετικά λήμματα [TFRecord and tf.Example](https://www.tensorflow.org/tutorials/load_data/tfrecord) και [tf.data: Build TensorFlow input pipelines](https://www.tensorflow.org/guide/data).
#
# Σημειώστε ότι με τη μέθοδο αυτή θα πρέπει να γίνει import η `tensorflow_datasets` και να χρησιμοποιήσουμε την `tfds.load` ώστε να αποθηκευθεί το σύνολο δεδομένων σε αρχεία tfrecord στο δίσκο (δείτε [εδώ](https://colab.research.google.com/github/tensorflow/datasets/blob/master/docs/overview.ipynb) ένα παράδειγμα). Φυσικά μπορούμε να μετατρέψουμε και τα πρωτογενή δεδομένα (raw data) του dataset όπως αρχεία jpg σε φορματ tfrecord όπως [εδώ](https://towardsdatascience.com/working-with-tfrecords-and-tf-train-example-36d111b3ff4d).

# %% [markdown]
# ### Υπερεκπαίδευση
#
# Μπορείτε να πειραματιστείτε ως προς τον έλεγχο της υπερεκπαίδευσης (overfitting) με διάφορους τρόπους. Μεταξύ αυτών μπορούμε να αναφέρουμε τους εξής:
# - Πρόωρος τερματισμός (early stopping). Μια μέθοδος που τερματίζει την εκπαίδευση αν δεν υπάρχει βελτίωση ως προς τη μετρική απόδοσης που παρακολουθούμε. [tf.keras.callbacks.EarlyStopping](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStoppinghttps://)
# - Dropout. Μια άλλη τεχνική για τη μείωση της υπερεκπαίδευσης είναι το Dropout. Είναι ένα είδος ομαλοποίησης (regularization) που επιβάλλει στα βάρη του δικτύου να παίρνουν μόνο μικρές τιμές. Εάν εφαρμόσουε dropout σε ένα επίπεδο του δικτύου, τότε ένα ποσοστό των βαρών του γίνεται τυχαία μηδενικό κατά την εκπαίδευση. [Dropout](https://www.tensorflow.org/tutorials/images/classification#dropout)
# - Επαύξηση δεδομένων. Η υπερεκπαίδευση συνήθως συμβαίνει όταν έχουμε λίγα ή/και πολύ όμοια δεδομένα εκπαίδευσης. Ένας τρόπος να διορθωθεί αυτό το πρόβλημα είναι να αυξήσουμε τα δεδομένα (data augmentation). Το data augmentation δημιουργεί νέα δεδομένα εκπαίδευσης με βάση τα υπάρχοντα εφαρμόζοντας τυχαίους μετασχηματισμούς ώστε να προκύπτουν αληθοφανείς εικόνες. [Data augmentation](https://www.tensorflow.org/tutorials/images/classification#data_augmentation), [ImageDataGenerator](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator#class_imagedatagenerator)
#
# Βλέπε επίσης [Image classification](https://www.tensorflow.org/tutorials/images/classification).

# %% [markdown]
# ### Χρόνος εκπαίδευσης
#
# Το TensorFlow 2 προσφέρει νέους ή βελτιώνει διάφορους μηχανισμούς βελτιστοποίησης της εκπαίδευσης. Μεταξύ αυτών έχουμε τους εξής:
# - Data prefetching (το χρησιμοποιήσαμε παραπάνω)
# - Data reading parallelization
# - Map transformation parallelization
# - Caching
# - Reducing memory footprint
#
# Συμβουλευτείτε για τα παραπάνω το [Better performance with the tf.data API](https://www.tensorflow.org/guide/data_performance)

# %% [markdown]
# ### Εργαλεία υψηλού επιπέδου
#
# Μεταξύ των εργαλείων βελτιστοποίησης υψηλού επιπέδου (high-level) του TensorFlow μπορούμε να αναφέρουμε τα ακόλουθα:
#
# - [TensorBoard](https://www.tensorflow.org/tensorboard/get_started) και [What-If Tool](https://www.tensorflow.org/tensorboard/what_if_tool) Επικουρικό εργαλείο οπτικοποίησης/ανάλυσης για τον πειραματισμό στη εκπαίδευση
# - [tf-explain](https://tf-explain.readthedocs.io/en/latest/) Προσφέρει μεθόδους επεξηγισιμότητας για το tf2
# - [Keras Tuner](https://github.com/keras-team/keras-tuner) Βελτιστοποίηση υπερπαραμέτρων του Keras στο TensorFlow 2.0
# - [AutoAugment](https://github.com/tensorflow/models/tree/master/research/autoaugment) Εκμάθηση της πολιτικης επαύξησης από τα δεδομένα

# %% [markdown]
# # Για τις χριστουγεννιάτικες διακοπές
#
# ## What's next for Deep Learning
#
# The Godfathers of AI and 2018 ACM Turing Award winners Geoffrey Hinton, Yann LeCun, and Yoshua Bengio shared a stage in New York on Sunday night at an event organized by the Thirty-Fourth AAAI Conference on Artificial Intelligence (AAAI 2020). The trio of researchers have made deep neural networks a critical component of computing, and in individual talks and a panel discussion they discussed their views on current challenges facing deep learning and where it should be heading.

# %%
from IPython.display import IFrame
IFrame(src='https://www.youtube.com/embed/UX8OubxsY8w', width=640, height=480)
# Out:
#         <iframe
#             width="640"
#             height="480"
#             src="https://www.youtube.com/embed/UX8OubxsY8w"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Αντίλογος: η κριτική του Schmidhuber για τους LeCun & Bengio & Hinton
#
# (Ο Schmidhuber και ο Hochreiter [εισήγαγαν τα LSTM το 1997](https://www.bioinf.jku.at/publications/older/2604.pdf))
#
# *Machine learning is the science of credit assignment. The machine learning community itself profits from proper credit assignment to its members. The inventor of an important method should get credit for inventing it. She may not always be the one who popularizes it. Then the popularizer should get credit for popularizing it (but not for inventing it). Relatively young research areas such as machine learning should adopt the honor code of mature fields such as mathematics: if you have a new theorem, but use a proof technique similar to somebody else's, you must make this very clear. If you "re-invent" something that was already known, and only later become aware of this, you must at least make it clear later.*
#
# *As a case in point, let me now comment on a recent article in [Nature (2015) about "deep learning"](http://www.nature.com/nature/journal/v521/n7553/full/nature14539.html) in artificial neural networks (NNs), by LeCun & Bengio & Hinton (LBH for short), three CIFAR-funded collaborators who call themselves the "deep learning conspiracy" (e.g., LeCun, 2015). They heavily cite each other. Unfortunately, however, they fail to credit the pioneers of the field, which originated half a century ago. All references below are taken from the recent [deep learning overview](http://www.idsia.ch/~juergen/deep-learning-overview.html) (Schmidhuber, 2015), except for a few papers listed beneath this critique focusing on nine items.*
#
# [Read more...](http://people.idsia.ch/~juergen/deep-learning-conspiracy.html)
